# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Lesson 09: Functions ##

# %% [markdown]
# ## Functions ##

# %%
# Define a simple function called triple that takes an argument, x, and multiplies it by 3.

# %%
# Call the function triple on a number

# %%
# Assign the whole number of your choice to num.
num =

# %%
# Call the function triple on num

# %%
# Call the function triple on num times 5.

# %% [markdown]
# ### Note About Scopes

# %%
x

# %%
# Why did we get an error message? Respond in this cell on the line below. 
#

# %%
x = 5

# %%
#Think about the output before you run this cell. 
triple(2 * x)

# %%
x

# %% [markdown]
# ### Type Agnostic

# %%
# Use the triple function on a string of your choice.

# %%
# Use the triple function on an array that includes the values 0 to 3.

# %% [markdown]
# ### Multiple Arguments
#
# $ h^2 = x^2 + y^2 \hspace{20 pt} => \hspace{20 pt} h = \sqrt{ x^2 + y^2 } $

# %%
#Complete the function below that will compute the hypotenuse. 
def hypotenuse(x,y):
    ...

# %%
#Try out your function.
hypotenuse(9, 12)

# %%
#Compute the hypotenuse of a isosceles right triangle with sides of 2 units

# %% [markdown]
# ## Apply ##

# %%
office = Table().with_columns(
    'Person', make_array('Jim', 'Pam', 'Michael', 'Creed'),
    'Birth Year', make_array(1985, 1988, 1967, 1904)
)
office

# %%
def age_in_2026(x):
    return 2026 - x

# %%
#How old are you, or will you be, in 2026?

# %%
#How old is, or will someone be, born in 1978?

# %%
# Apply the age_in_2026 function to find the age of every individual in the table
office.apply(...)

# %%
def greeting(person):
    return 'Dunder Mifflin, this is ' + person

# %%
greeting('Pam')

# %%
# Apply the greeting function to your name.

# %%
office.apply(greeting, 'Person')

# %%
# Create function with two arguments
def name_and_age(name, year):
    ...

# %%
# apply function to two columns from our table
office.apply(name_and_age, 'Person', 'Birth Year')
